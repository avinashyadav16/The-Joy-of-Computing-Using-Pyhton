# %% [markdown]
# # <center><b>WEEK - 08</b></center>

# %% [markdown]
# # <b>TUPLES:</b>

# %% [markdown]
# <pre>
# Tuples have the given characteristics:
#   ➡️  They are indexed
#   ➡️  Tuples are ordered
#   ➡️  These are immutable
#   ➡️  They can contain duplicate items
# </pre>

# %%
ice_cream_flavours = ("Vanilla", "Chocolate", "Butterscotch",
                      "Strawberry", "Mint Chocolate Chip")
print(ice_cream_flavours)
print(type(ice_cream_flavours))
# Out:
# ('Vanilla', 'Chocolate', 'Butterscotch', 'Strawberry', 'Mint Chocolate Chip')
# <class 'tuple'>

# %%
for flavours in ice_cream_flavours:
    print(flavours)
# Out:
# Vanilla
# Chocolate
# Butterscotch
# Strawberry
# Mint Chocolate Chip

# %%
# IndexError: tuple index out of range
ice_cream_flavours[10]

# %%
# TypeError: 'tuple' object does not support item assignment
ice_cream_flavours[3] = "Pineapple Cane"

# %%
len(ice_cream_flavours)
# Out:
# 5

# %%
print(ice_cream_flavours.count("vanila"))             # Not Present
print(ice_cream_flavours.count("Vanilla"))            # Present
# Out:
# 0
# 1

# %%
print(ice_cream_flavours.index("Vanilla"))            # Present at index 0
# Not Present: ValueError: tuple.index(x): x not in tuple
print(ice_cream_flavours.index("vanila"))

# %% [markdown]
# <br><br>
#
# # <b>Lottery Simulation - Profit or Loss</b><br>

# %%
# A small prototype of the above stated problem:
# ₹100 is entry fee for each game
# ₹900 is winning money on correct bet

import random

user_bet = int(input("Your bet{1-10}: "))
lucky_draw = random.randint(1, 10)

game_money = 0
print("You Bet on: ", user_bet)
print("Lucky Draw is: ", lucky_draw)

if user_bet == lucky_draw:
    game_money = game_money + 900 - 100

else:
    game_money = game_money - 100

print(game_money)
# Out:
# You Bet on:  8
# Lucky Draw is:  6
# -100

# %%
# Actual Working solution for a week:

import random

game_money = 0
week = 7

for day in range(week):
    user_bet = random.randint(1, 10)
    lucky_draw = random.randint(1, 10)

    print("Bet is on: ", user_bet)
    print("Lucky Draw is: ", lucky_draw)

    if user_bet == lucky_draw:
        game_money = game_money + 900 - 100

    else:
        game_money = game_money - 100

    print("Account Money in game: ₹{}".format(game_money))
    print()
# Out:
# Bet is on:  9
# Lucky Draw is:  9
# Account Money in game: ₹800
#
# Bet is on:  4
# Lucky Draw is:  10
# Account Money in game: ₹700
#
# Bet is on:  8
# Lucky Draw is:  10
# Account Money in game: ₹600
#
# Bet is on:  6
# Lucky Draw is:  7
# Account Money in game: ₹500
#
# Bet is on:  1
# Lucky Draw is:  5
# Account Money in game: ₹400
#
# Bet is on:  2
# Lucky Draw is:  10
# Account Money in game: ₹300
#
# Bet is on:  10
# Lucky Draw is:  9
# Account Money in game: ₹200

# %%
# Actual Working solution for a year:

import random
import matplotlib.pyplot as plt

# Axes X and Y
x = []
y = []

game_money = 0
month = 30
year = 12

for month in range(year+1):
    x.append(month+1)
    for day in range(month+1):
        user_bet = random.randint(1, 10)
        lucky_draw = random.randint(1, 10)

        if user_bet == lucky_draw:
            game_money = game_money + 900 - 100

        else:
            game_money = game_money - 100
    y.append(game_money)

    print("Account Money in {} month in game: ₹{}".format(month+1, game_money))
    print()


plt.plot(x, y)
plt.show()
# Out:
# Account Money in 1 month in game: ₹-100
#
# Account Money in 2 month in game: ₹-300
#
# Account Money in 3 month in game: ₹-600
#
# Account Money in 4 month in game: ₹-100
#
# Account Money in 5 month in game: ₹-600
#
# Account Money in 6 month in game: ₹600
#
# Account Money in 7 month in game: ₹800
#
# Account Money in 8 month in game: ₹0
#
# Account Money in 9 month in game: ₹0
#
# Account Money in 10 month in game: ₹-1000
#
# Account Money in 11 month in game: ₹-1200
#
# Account Money in 12 month in game: ₹-600
#
# Account Money in 13 month in game: ₹-1000

# %% [markdown]
# <br><br>
#
# # <b>Image Processing - Enhance your images</b><br>

# %% [markdown]
# ### Flipping The Image

# %%
# Flipping the Image:
from PIL import Image

# Opeing the image:
img = Image.open("evidence.jpg")

# transposing the image:
transposed_img = img.transpose(Image.FLIP_LEFT_RIGHT)

# Converting into human understable form:
transposed_img.save('corrected_evidence.jpg')

# Checking that everything went right:
print("Done Flipping.")
# Out:
# Done Flipping.

# %% [markdown]
# ### Enhancing the Image

# %%
# IMAGE ENHACEMENT TECHNIQUE: Adaptive Histogram Equalisation( CLAHE- Contrast-limited adaptive histogram equalization)

import cv2

# Read the image
img = cv2.imread('bullet_shots.jpeg')

# Preparation for CLAHE( works well for black and white images)
cv2.createCLAHE()

# Converting into Gray scale image:
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Create a CLAHE object:
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

# Applying Enhacement:
enh_img = clahe.apply(gray_img)

# saving the image:
cv2.imwrite('enhanced_bullet.jpeg', enh_img)

# Confirmting
print("Done Enhancing.")
# Out:
# Done Enhancing.

# %% [markdown]
# <br><br>
#
# # <b>ANAGRAMS</b><br>

# %% [markdown]
# ![Alt text](image.png)

# %% [markdown]
# ![Alt text](image-3.png)

# %% [markdown]
# ![Alt text](image-4.png)

# %%
str1 = input("Enter string-1: ")
str2 = input("Enter string-2: ")

print("String-1: ", str1)
print("String-2: ", str2)
print()

print(sorted(str1))
print(sorted(str2))
print()

if (sorted(str1) == sorted(str2)):
    print("Thses are anagrams.")
else:
    print("These are not anagrams.")
# Out:
# String-1:  tea
# String-2:  ate
#
# ['a', 'e', 't']
# ['a', 'e', 't']
#
# Thses are anagrams.

# %% [markdown]
# <br><br>
#
# # <b>FACEBOOK SENTIMENT ANALYSIS</b><br>

# %% [markdown]
# ![Alt text](image-1.png)

# %% [markdown]
# ![Alt text](image-2.png)

# %% [markdown]
# ![Alt text](image-5.png)

# %% [markdown]
# ![Alt text](image-6.png)

# %% [markdown]
# ![Alt text](image-7.png)

# %% [markdown]
# ![Alt text](image-8.png)

# %% [markdown]
# ![Alt text](image-9.png)

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.downloader.download('vader_lexicon')
file = '<fileName>.xslsx'       # Keep your excel file name here

# Reading the Excel File:
xl = pd.ExcelFile(file)

# Converting Excel files to dataframes
# Enter the column in which all the information is stored.
dfs = xl.parse(xl.sheet_names[0])

# Updating the dataframes by removing the blank rows:
# Timeline - name of the column
dfs = list(dfs['Timeline'])

print(dfs)

# Doing the sentiment analysis:
sid = SentimentIntensityAnalyzer()

str1 = "UTC+05:30"
for data in dfs:
    a = data.find(str1)

    # Working on rows that does not have UTC+05:30 and leaving all the other rows
    if (a == -1):
        ss = sid.polarity_scores(data)
        print(data)

        # Now take k to denote sentiment and ss[k] is the intensity of the sentiment
        for k in ss:
            print(k, ss[k])

# %% [markdown]
# > <br><br><br><br>
# >
# > # <center><b>Week 8 : Assignment</b></center>
# >
# > <br><br><br><br>

# %% [markdown]
# ## <center><b>QUESTION - 01</b></center>

# %% [markdown]
# ![Alt text](image-12.png)

# %% [markdown]
# ## <center><b>QUESTION - 02</b></center>

# %% [markdown]
# ![Alt text](image-13.png)

# %% [markdown]
# ## <center><b>QUESTION - 03</b></center>

# %% [markdown]
# ![Alt text](image-14.png)

# %%
t = (1, 2, 3, 4, 5)

for i in range(-1, -len(t), -1):
    print(t[i])
# Out:
# 5
# 4
# 3
# 2

# %% [markdown]
# ## <center><b>QUESTION - 04</b></center>

# %% [markdown]
# ![Alt text](image-15.png)

# %%
word = 'facebook'
new = ''

for w in word:
    i = ord(w)

    j = (((i + 26) - 97) % 26) + 97

    new = new + chr(j)

print(new)
# Out:
# facebook

# %% [markdown]
# ## <center><b>QUESTION - 05</b></center>

# %% [markdown]
# ![Alt text](image-16.png)

# %%
print('Enter a letter between a-z: ')

player1 = str(input())
player2 = str(input())

while (True):
    if (ord(player1.lower()) + 1 == ord(player2.lower())):
        print("Clap")
        break
    else:
        playerl = str(input())
        player2 = str(input())
# Out:
# Enter a letter between a-z:
# Clap

# %% [markdown]
# ## <center><b>QUESTION - 06</b></center>

# %% [markdown]
# ![Alt text](image-17.png)

# %%
import random
import matplotlib.pyplot as plt

l = []
count = 0

for i in range(10):
    guess = random.randint(1, 10)
    pick = random.randint(1, 10)
    print(guess, end=" ")
    print(pick, end=" ")
    print()

    if (guess != pick):
        count += 1
        l.append(count)
    else:
        count -= 1
        l.append(count)

plt.plot(l)
plt.show()
# Out:
# 3 5
# 2 2
# 2 1
# 2 8
# 10 4
# 8 2
# 4 8
# 5 4
# 3 10
# 8 10

# %% [markdown]
# ## <center><b>QUESTION - 07</b></center>

# %% [markdown]
# ![Alt text](image-18.png)

# %% [markdown]
# ## <center><b>QUESTION - 08</b></center>

# %% [markdown]
# ![Alt text](image-19.png)

# %%
string = 'hey!there'

a = sorted(string)
a.reverse()

print(a)
# Out:
# ['y', 't', 'r', 'h', 'h', 'e', 'e', 'e', '!']

# %% [markdown]
# ## <center><b>QUESTION - 09</b></center>

# %% [markdown]
# ![Alt text](image-20.png)

# %% [markdown]
# ## <center><b>QUESTION - 10</b></center>

# %% [markdown]
# ![Alt text](image-21.png)

# %% [markdown]
# <br><br><br><br>
#
# # <center><b> PROGRAMMING ASSIGNMENT - 01:</b></center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def squareT(T):
    square_ele = tuple(x*x for x in T)
    return T + square_ele


if __name__ == "__main__":
    n = int(input())
    new_List = list(map(int, input().split()))
    T = tuple(new_List)
    ans = squareT(T)
    if type(ans) == type(T):
        print(ans)

# %% [markdown]
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# <br><br><br><br>
#
# # <center><b> PROGRAMMING ASSIGNMENT - 02:</b></center>

# %% [markdown]
# ![Alt text](image-10.png)

# %%
def replaceV(S):
    vowels = list("aeiouAEIOU")
    L = list(S)

    for i in range(len(L)-2):
        if L[i] in vowels and L[i+1] in vowels and L[i+2] in vowels:
            L[i] = '*'
            L[1+i] = "*"
            L[i+2] = "*"
            i += 2

    return ("".join(L).replace("***", "_"))


print(replaceV(input()), end="")


S = input()
print(replaceV(S))

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# <br><br><br><br>
#
# # <center><b> PROGRAMMING ASSIGNMENT - 03:</b></center>

# %% [markdown]
# ![Alt text](image-11.png)

# %%
def shiftZeroesRight(L):
    num_zeros = 0

    # Move non-zero elements to the left
    for i in range(len(L)):
        if L[i] != 0:
            L[i - num_zeros] = L[i]
        else:
            num_zeros += 1

    # Fill the end of the list with zeros
    for i in range(len(L) - num_zeros, len(L)):
        L[i] = 0

    return L


n = 10
new_List = list(map(int, input().split()))
result = shiftZeroesRight(new_List)
print(result, end="")

# %% [markdown]
# ![image-11.png](attachment:image-11.png)
