# %% [markdown]
# <h1 align="center"><b><u> WEEK - 07 </u></b></h1>
#
# <br><br><br>

# %% [markdown]
# <br><br>
#
# ---
# ---
#
# <br>
#
# <h1 align="center"><b><u> SNAKES AND LADDERS </u></b></h1>
#
# ---
# ---

# %% [markdown]
# The reference snake and ladder board:

# %% [markdown]
# ![SL - 01](attachment:image.png)

# %%
import random

# importing the image library:
from PIL import Image

# The end point of the board:
end = 100


def show_board():
    # importing the image
    img = Image.open('image-6.png')

    # Showing the image:
    img.show()




def check_ladder(points):
    if points == 8:
        print("Ladder")
        return 26
    elif points == 21:
        print("Ladder")
        return 82
    elif points == 43:
        print("Ladder")
        return 77
    elif points == 50:
        print("Ladder")
        return 91
    elif points == 54:
        print("Ladder")
        return 93
    elif points == 62:
        print("Ladder")
        return 96
    elif points == 66:
        print("Ladder")
        return 87
    elif points == 80:
        print("Ladder")
        return 100
    else:
        # no ladder
        return points




def check_snake(points):
    if points == 44:
        print("Snake")
        return 22
    elif points == 46:
        print("Snake")
        return 5
    elif points == 48:
        print("Snake")
        return 9
    elif points == 52:
        print("Snake")
        return 11
    elif points == 55:
        print("Snake")
        return 7
    elif points == 59:
        print("Snake")
        return 17
    elif points == 64:
        print("Snake")
        return 36
    elif points == 69:
        print("Snake")
        return 33
    elif points == 73:
        print("Snake")
        return 1
    elif points == 83:
        print("Snake")
        return 19
    elif points == 95:
        print("Snake")
        return 24
    elif points == 98:
        print("Snake")
        return 28
    else:
        # no snake
        return points


def reached_end(points):
    if points == end:
        return True
    else:
        return False





def play():
    # Player-1 name:
    p1_name = input("Enter Player-1 Name: ")

    # Player-2 name:
    p2_name = input("Enter Player-2 Name: ")

    # intial point of player-1&2
    pp1 = pp2 = 0

    turn = 0
    # turn - 0, 2, 4, 6 are for player_1
    # turn - 1, 3, 5 are for player_2

    while (1):
        if turn % 2 == 0:
            print()
            # player-1 turn:
            print(p1_name, "Your turn")

            # asking player's choice to continue:
            choice = int(input("Enter 1 to continue; 0 to quit: "))
            if (choice == 0):
                print()
                print(p1_name, "scored: ", pp1)
                print(p2_name, "scored: ", pp2)
                print("Exiting from the game...")
                break

            # genrating random number from 1 to 6
            dice = random.randint(1, 6)
            print("Dice showed: ", dice)

            pp1 += dice
            pp1 = check_ladder(pp1)
            pp1 = check_snake(pp1)

            # check when player goes beyond the board:
            if pp1 > end:
                pp1 = end

            print(p1_name, "Your score: ", pp1)

            if reached_end(pp1):
                print(p1_name, "won")
                end


        # this is for player - 2
        else:
            print()
            # player-2 turn:
            print(p2_name, "Your turn")

            # asking player's choice to continue:
            choice = int(input("Enter 1 to continue; 0 to quit: "))
            if (choice == 0):
                print()
                print(p1_name, "scored: ", pp1)
                print(p2_name, "scored: ", pp2)
                print("Exiting from the game...")
                break

            # genrating random number from 1 to 6
            dice = random.randint(1, 6)
            print("Dice showed: ", dice)

            pp2 += dice
            pp2 = check_ladder(pp2)

            pp2 = check_snake(pp2)

            # check when player goes beyond the board:
            if pp2 > end:
                pp2 = end

            print(p2_name, "Your score: ", pp2)

            if reached_end(pp2):
                print(p2_name, "won")
                end

        turn += 1



# Showing the snake and ladder board for the player:
show_board()


# Asking the player to play:
play()
# Out:
# Avinash Your turn
# Dice showed:  4
# Avinash Your score:  4
#
# jay Your turn
# Dice showed:  6
# jay Your score:  6
#
# Avinash Your turn
# Dice showed:  2
# Avinash Your score:  6
#
# jay Your turn
# Dice showed:  3
# jay Your score:  9
#
# Avinash Your turn
# Dice showed:  2
# Ladder
# Avinash Your score:  26
#
# jay Your turn
# Dice showed:  3
# jay Your score:  12
#
# Avinash Your turn
# Dice showed:  4
# Avinash Your score:  30
#
# jay Your turn
# Dice showed:  4
# jay Your score:  16
#
# Avinash Your turn
# Dice showed:  2
# Avinash Your score:  32
#
# jay Your turn
# Dice showed:  2
# jay Your score:  18
#
# Avinash Your turn
# Dice showed:  3
# Avinash Your score:  35
#
# jay Your turn
# Dice showed:  2
# jay Your score:  20
#
# Avinash Your turn
# Dice showed:  4
# Avinash Your score:  39
#
# jay Your turn
#
# Avinash scored:  39
# jay scored:  20
# Exiting from the game...

# %% [markdown]
# <br><br><br>

# %% [markdown]
# <br><br>
#
# ---
# ---
#
# <br>
#
# <h1 align="center"><b><u> Spiral Traversing - Let's Animate </u></b></h1>
#
# ---
# ---

# %%
from random import randint

import turtle

# Turtle canva background colour
turtle.bgcolor("black")

# Creating turtle
tur = turtle.Turtle()

# Creating the dot dimeansion to represent/replace the matrix element
width = 5
height = 7

# after printing the dot moving the desired distance:
dot_distance = 25


tur.penup()
list_color = ["white", "yellow", "brown", "red", "blue", "green", "orange", "pink", "violet", "grey", "cyan"]


# Setting the initial position of the turtle:
tur.setpos(-250, 250)



def spiral (m, n):
    k = 0
    l = 0
    '''
        m = ending row index
        n = ending column index
        k = index of starting row
        l = index of starting column
        i = iterator
    '''
    
    # for turtle's angle movements:
    f = 0
    
    # Color of the dot to be white as the bg is black:
    tur.color("white")

    col = randint(0, 10)
    tur.color(list_color[col])
    while(k<m and l<n):
        
        if(f==1):
            tur.right(90)
        
        # Printing the first row from the remaining rows
        for i in range(l, n):
            tur.dot()
            tur.forward(dot_distance)
            # print(arr[k][i], end=" ")
        k += 1
        f = 1
        
        # reaching downward, so changing the angle again:
        tur.right(90)
        col = randint(0, 10)
        tur.color(list_color[col])
        # Printing the last column from the remaining column
        for i in range(k,m):
            tur.dot()
            tur.forward(dot_distance)
            # print(arr[i][n-1], end=" ")
        n -= 1
        
        
        tur.right(90)
        col = randint(0, 10)
        tur.color(list_color[col])
        if(k<m):
            # printing the last row from remaining rows
            for i in range(n-1, l-1, -1):
                tur.dot()
                tur.forward(dot_distance)
                # print(arr[m-1][i], end=" ")
            m -= 1

        tur.right(90)
        col = randint(0, 10)
        tur.color(list_color[col])
        if(l<n):
            # printing the first column from the remaining columns
            for i in range(m-1, k-1, -1):
                tur.dot()
                tur.forward(dot_distance)
                # print(arr[i][l], end=" ")
            l += 1
                            
                            
# arr = []
# count = 1
# for i in range(4):
#     l = []
#     for j in range(4):
#         l.append (count)
#         count+=1
#     arr.append(l)                           
    
# spiral(4, 4, arr)
  
spiral(20, 20)

# %% [markdown]
# The Output will be somewhat like this(except the colour sequence.)

# %% [markdown]
# ![ST - 01](attachment:image.png)

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <br><br>
#
# ---
# ---
#
# <br>
#
# <h1 align="center"><b><u> GPS - Track the route </u></b></h1>
#
# ---
# ---

# %% [markdown]
# ![GPS - 01](attachment:image.png)

# %% [markdown]
# ![GPS - 02](attachment:image.png)

# %% [markdown]
# <br><br><br><br><br><br><br><br>
#
# ---
#
# ---
#
# > <br><br><br><br>
# >
# > <h1 align="center"><b><u> Week 07: Assignment </u></b></h1>
# >
# > <br><br><br><br>
#
# ---
#
# ---

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 01 </u></b></h1>

# %% [markdown]
# ![Q1](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 02 </u></b></h1>

# %% [markdown]
# ![Q2.1](attachment:w7q2.jpg)
#
# ![Q2.2](attachment:image.png)

# %%
def spiral(row, column, arr):
    rowStart = 0
    columnStart = 0

    while (rowStart < row and columnStart < column):

        for i in range(rowStart, row):
            print(arr[i][columnStart], end=" ")

        columnStart += 1

        for i in range(columnStart, column):
            print(arr[row-1][i], end=" ")

        row -= 1

        if (rowStart < row):
            for i in range(row-1, rowStart-1, -1):
                print(arr[i][column-1], end=" ")
            column -= 1

        if (columnStart < column):
            for i in range(column-1, columnStart-1, -1):
                print(arr[rowStart][i], end=" ")
            rowStart += 1


matrix = [[1, 2, 3],
          [5, 6, 7],
          [9, 10, 11]]

row = 3
column = 3

spiral(row, column, matrix)
# Out:
# 1 5 9 10 11 7 3 2 6

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 03 </u></b></h1>

# %% [markdown]
# ![Q3.1](attachment:w7q3.jpg)
#
# ![Q3.2](attachment:image.png)

# %%
import turtle

pen = turtle.Turtle()

for i in range(3):

    pen.forward(60)
    pen.right(120)

turtle.done()

# %% [markdown]
# ![Output - 03](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 04 </u></b></h1>

# %%
import turtle

pen = turtle.Turtle()

for i in range(6):

    pen.forward(30)
    pen.right(60)

turtle.done()

# %% [markdown]
# ![Output - 04](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 05 </u></b></h1>

# %% [markdown]
# ![Q5](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 06 </u></b></h1>

# %% [markdown]
# ![Q6.1](attachment:w7q6.jpg)
#
# ![Q6.2](attachment:image.png)

# %%
import turtle

pen = turtle.Turtle()

for i in range(3):

    pen.right(60)
    pen.forward(60)
    pen.penup()
    pen.right(60)
    pen.forward(60)
    pen.pendown()

turtle.done()

# %% [markdown]
# ![Output - 06](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 07 </u></b></h1>

# %% [markdown]
# ![Q7](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 08 </u></b></h1>

# %% [markdown]
# ![Q8](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 09 </u></b></h1>

# %% [markdown]
# ![Q9](attachment:image.png)

# %% [markdown]
# <h1 align="center"><b><u> QUESTION - 10 </u></b></h1>

# %% [markdown]
# ![Q10](attachment:image.png)

# %% [markdown]
# <br><br><br><br>
#
# ---
#
# ---
#
# <br><br>
#
# <h1 align="center"><b><u> PROGRAMMING ASSIGNMENT - 01: </u></b></h1>
# <br><br>

# %% [markdown]
# ![PA - 01](attachment:image.png)

# %%
def DiagCalc(matrix):
    left_sum = 0
    right_sum = 0
    rev_mat = matrix[::-1]

    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if i == j:
                left_sum += matrix[i][j]
                right_sum += rev_mat[i][j]

    print(left_sum)
    print(right_sum, end="")


n = int(input())
M = []
for i in range(n):
    L = list(map(int, input().split()))
    M.append(L)

DiagCalc(M)

# %% [markdown]
# ![PA - 0101](attachment:image.png)

# %% [markdown]
# <br><br><br><br>
#
# ---
#
# ---
#
# <br><br>
#
# <h1 align="center"><b><u> PROGRAMMING ASSIGNMENT - 02: </u></b></h1>
# <br><br>

# %% [markdown]
# ![PA - 02](attachment:image.png)

# %%
import numpy
from array import *


def Transpose(M):
    arrays = numpy.array(M)
    num_list = arrays.transpose().tolist()
    return (num_list)


n = int(input())
M = []
for i in range(n):
    L = list(map(int, input().split()))
    M.append(L)
print(Transpose(M))

# %%
import numpy


def Transpose(M):
    return numpy.transpose(M)


n = int(input())
M = []
for i in range(n):
    L = list(map(int, input().split()))
    M.append(L)
print(Transpose(M))

# %% [markdown]
# ![PA - 0202](attachment:image.png)

# %% [markdown]
# <br><br><br><br>
#
# ---
#
# ---
#
# <br><br>
#
# <h1 align="center"><b><u> PROGRAMMING ASSIGNMENT - 03: </u></b></h1>
# <br><br>

# %% [markdown]
# ![PA - 03](attachment:image.png)

# %%
def snake(M):
    snake_matrix_row = 0
    snake_matrix = []

    for row in M:
        emp_list = []
        snake_matrix_row += 1

        if snake_matrix_row % 2 == 0:
            emp_list = row[::-1]

        else:
            emp_list = row

        snake_matrix += emp_list

    return snake_matrix


n = int(input())
M = []
for i in range(n):
    L = list(map(int, input().split()))
    M.append(L)

print(snake(M))

# %% [markdown]
# ![PA - 0303](attachment:image.png)

# %% [markdown]
# --------------------------
# -------------------------
#
# <br><br>
# <h1 style="color: red" align="center"><b>*<u>  THE END  </u>*</b></h1>
# <br><br>
#
#
# ------------------------------
# -----------------------------
